# %% [markdown]
# # 30254 - ML for Public Policy HW5 - Nora Hajjar

# %% [markdown]
# ## Machine Learning Pipeline Version 3 (HW5):
#
# The goal of this homework assignment is to use the feedback from HW3 to fix and update your ML pipeline. The assignment is to redo HW3 and submit the answers again.

# %% [markdown]
# HW 3 Feedback
#
#
# PART 1: Pipeline (18/40)
#
# Models (10/10)
# ● The models need to be implemented but also written efficiently and in a reusable manner
# ● You implemented different models in a modularized way, but it seems that your code in line
# 169-293 in your pipeline is not used when you call the model?
#
# Model Parameters (3/10)
# ● It seems that your run_models function can take in different models with different parameters, but
# your code in the pipeline didn’t show how it takes care of different parameters of a single model
#
# Metrics (1/10)
# ● Should be calculated on % of population and not on score thresholds
# ● You didn’t choose the thresholds responding to how many percentage of projects will be
# predicted with label 1
# ● In your precision and recall curve, you should plot the value of precision and recall against the
# value of threshold, but you plot precision against recall. Also the threshold is not translated to the
# percentile of the population
#
# Temporal Validation (4/10)
# ● Leaving gap between end of training and for the labels/outcomes to happen
# ● Your temporal validation functions are well organized. However, you didn’t take care of the
# requirement that the first posting date for test data should be 60 days after the end posting date,
# since you need 60 days to know the result of the train data
# ● Moreover, you shouldn’t choose the start and end date of training & test data manually
#
#
# PART 2: Run the code on the donors choose problem (23/40)
#
# Prep data (0/2)
# ● What’s the line [54] - [65] in ipynb doing here? You need to modularize your preprocessing of the
# data as functions in the pipeline. It’s confusing for the reader to see all the details and the
# repetitions in your manipulation
# ● You shouldn’t preprocess the data before splitting the training and data set. By doing the data
# imputation you violated the independency of the two sets of data
#
# Get label (4/4)
# ● You corrected computed the label
#
# Generate Features (3/4)
# ● You shouldn’t hardcode the categorical features that need to be converted
#
# Training and test sets (8/10)
# ● You split the temporal training and test data, but they are wrong since your pipeline is wrong
#
# Models and hyperparameters (4/10)
# ● The code in experiment with different parameters section in ipynb is confusing. It seems that you
# are only dealing with bagging and didn’t experiment other models
# ● You need to modularize the experimentation on different models in the pipeline
#
# Metrics (4/10)
# ● You report the evaluation with different metrics and they are wrong in your pipeline, and you
# didn’t plot the precision recall curve
#
#
# PART 3: Write up the results (5/10)
# ● You need a more comprehensive discussion about how the different models perform with respect
# to different metrics
# ● Also it’s not clear how you explain the change of the data over time
#
#
# PART 4: Code quality: (4/10)
# ● Your code in pipeline is in general modularized, although you should consider removing the
# separate functions evaluation different models
# ● Your code in ipynb is not efficient in demonstrating your data analysis process. Consider to wrap
# your code by functions and remove the repetitions and hardcodings
#
# Total: 50/100
#
# Note: If you believe you have implemented some function that I didn’t see, or my reading of your code is
# incorrect, please let me know. It’s a large coding assignment, and it’s possible that I could miss some
# details, and I would appreciate it if you point out my mistake to me!
# Annika Zhang , May 22 at 4:12pm

# %% [markdown]
# ### LOAD DATA

# %%
#import pipeline.py file
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import final_pipeline as p
import pandas as pd
import time
from datetime import date, datetime, timedelta
from dateutil.relativedelta import relativedelta
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = p.load_data('projects_2012_2013.csv')

# %%
#minor data prep follows. Pre-processing occurs AFTER temporal validation and creation of train/test splits

# %%
#show null counts
null_counts = p.check_null_counts(df)
null_counts
# Out:
# projectid                                     0
# teacher_acctid                                0
# schoolid                                      0
# school_ncesid                              9233
# school_latitude                               0
# school_longitude                              0
# school_city                                   0
# school_state                                  0
# school_metro                              15224
# school_district                             172
# school_county                                 0
# school_charter                                0
# school_magnet                                 0
# teacher_prefix                                0
# primary_focus_subject                        15
# primary_focus_area                           15
# secondary_focus_subject                   40556
# secondary_focus_area                      40556
# resource_type                                17
# poverty_level                                 0
# grade_level                                   3
# total_price_including_optional_support        0
# students_reached                             59
# eligible_double_your_impact_match             0
# date_posted                                   0
# datefullyfunded                               0
# dtype: int64

# %%
#drop columns that are irrelevant/too many nulls
df.drop(['school_ncesid', 'school_metro', 'secondary_focus_subject', 'secondary_focus_area'], axis=1, inplace=True)

# %%
#drop NA values for columns we can't fill in with avg
df.dropna(subset=['primary_focus_subject', 'primary_focus_area','resource_type', 'grade_level', 'school_district'], inplace=True)

# %%
#rest of nulls we will fill in after train/test splits 
#b/c numeric so we can fill in with avg
null_counts = p.check_null_counts(df)
null_counts
# Out:
# projectid                                  0
# teacher_acctid                             0
# schoolid                                   0
# school_latitude                            0
# school_longitude                           0
# school_city                                0
# school_state                               0
# school_district                            0
# school_county                              0
# school_charter                             0
# school_magnet                              0
# teacher_prefix                             0
# primary_focus_subject                      0
# primary_focus_area                         0
# resource_type                              0
# poverty_level                              0
# grade_level                                0
# total_price_including_optional_support     0
# students_reached                          53
# eligible_double_your_impact_match          0
# date_posted                                0
# datefullyfunded                            0
# dtype: int64

# %%
#check dtypes
df.dtypes
# Out:
# projectid                                  object
# teacher_acctid                             object
# schoolid                                   object
# school_latitude                           float64
# school_longitude                          float64
# school_city                                object
# school_state                               object
# school_district                            object
# school_county                              object
# school_charter                             object
# school_magnet                              object
# teacher_prefix                             object
# primary_focus_subject                      object
# primary_focus_area                         object
# resource_type                              object
# poverty_level                              object
# grade_level                                object
# total_price_including_optional_support    float64
# students_reached                          float64
# eligible_double_your_impact_match          object
# date_posted                                object
# datefullyfunded                            object
# dtype: object

# %%
#convert the dates to the appropriate type
p.convert_to_datetime(df, ['date_posted', 'datefullyfunded'])
df.dtypes
# Out:
# projectid                                         object
# teacher_acctid                                    object
# schoolid                                          object
# school_latitude                                  float64
# school_longitude                                 float64
# school_city                                       object
# school_state                                      object
# school_district                                   object
# school_county                                     object
# school_charter                                    object
# school_magnet                                     object
# teacher_prefix                                    object
# primary_focus_subject                             object
# primary_focus_area                                object
# resource_type                                     object
# poverty_level                                     object
# grade_level                                       object
# total_price_including_optional_support           float64
# students_reached                                 float64
# eligible_double_your_impact_match                 object
# date_posted                               datetime64[ns]
# datefullyfunded                           datetime64[ns]
# dtype: object

# %%
#create our date_diff column
df['days_to_funded'] = df.datefullyfunded - df.date_posted

# %%
p.convert_column_type(df, 'days_to_funded', 'timedelta64[D]')

# %%
df['not_fully_funded_60'] = df['days_to_funded'] > 60.0

# %%
df['not_fully_funded_60'] = df['not_fully_funded_60'] * 1

# %% [markdown]
# ### CREATE TEMPORAL VALIDATION TEST/TRAIN SPLITS

# %%
#automated method, based on Rayid function - switched from manual process
splits = p.temporal_validate('2012-01-01', '2013-12-31', [6], 60)

# %%
#now we have a list of train/test groups (6 total, based on the temporal validation groups that we have)
#time to pre-process the data before it goes into the models

# %%
df['eligible_double_your_impact_match_binary'] = df['eligible_double_your_impact_match'].map({'f':0, 't':1})

# %%
df['school_charter_binary'] = df['school_charter'].map({'f':0, 't':1})

# %%
df['school_magnet_binary'] = df['school_magnet'].map({'f':0, 't':1})

# %%
df['school_state_num'] = df.school_state.astype('category').cat.codes

# %%
df['school_city_num'] = df.school_city.astype('category').cat.codes

# %%
df['school_district_num'] = df.school_district.astype('category').cat.codes

# %%
df['school_county_num'] = df.school_county.astype('category').cat.codes

# %%
df['teacher_prefix_num'] = df.teacher_prefix.astype('category').cat.codes

# %%
df['primary_focus_subject_num'] = df.primary_focus_subject.astype('category').cat.codes

# %%
df['primary_focus_area_num'] = df.primary_focus_area.astype('category').cat.codes

# %%
df['resource_type_num'] = df.resource_type.astype('category').cat.codes

# %%
df['poverty_level_num'] = df.poverty_level.astype('category').cat.codes

# %%
df['grade_level_num'] = df.grade_level.astype('category').cat.codes

# %%
dep_var = 'not_fully_funded_60_binary'

pred_vars = ['total_price_including_optional_support', 
        'students_reached',
       'eligible_double_your_impact_match_binary', 
       'school_state_num',
       'school_city_num', 
       'school_district_num', 
       'school_county_num',
       'school_charter_binary', 
       'school_magnet_binary', 
       'teacher_prefix_num',
       'primary_focus_subject_num', 
       'primary_focus_area_num',
       'resource_type_num', 
       'poverty_level_num', 
       'grade_level_num']

# %%
#now, lets create a simplified table just with above columns that we want

df_full = df[['date_posted', 'not_fully_funded_60_binary', 'total_price_including_optional_support', 
        'students_reached',
       'eligible_double_your_impact_match_binary', 
       'school_state_num',
       'school_city_num', 
       'school_district_num', 
       'school_county_num',
       'school_charter_binary', 
       'school_magnet_binary', 
       'teacher_prefix_num',
       'primary_focus_subject_num', 
       'primary_focus_area_num',
       'resource_type_num', 
       'poverty_level_num', 
       'grade_level_num']].copy()

# %% [markdown]
# ### CREATE TEMPORAL VALIDATION TEST/TRAIN SPLITS

# %%
BEGIN HERE

# %%
#new guidelines from Rayid for splits, directly from session:
training 1: 1/1/2012 to 4/30/2012 (leave 60 days to see result of training data) you can define training as 1/1/2012 - 6/30/12 but you are only going to eval those that have posting dates 1/1/12-4/30/12 but the extra time is for those posted on like 4/29/12, 
    test 1: 7/1/2012 to 10/31/2012, you only eval those with posting dates 7/1/2012 to 10/31/2012 (so you have time to get the labels for those posted on 10/31/2012)
training 2: 1/1/2012 to 10/31/2012, 
    test 2: 1/1/2013 to 4/30/2013 with 4/30 - 6/30 for evaluation/getting labels
training 3: 1/1/2012 to 4/30/2013, 
    test 3: 7/1/2013 to 10/31/2013 with 10/31 to 12/31 for evaluation/getting labels

#updated with revised dates from Rayid, see above
#manual data, see temporal val function for automated data
#training data
train_1 = p.temp_val_train(df_full, 'date_posted', '2012-04-30')
train_2 = p.temp_val_train(df_full, 'date_posted', '2012-10-31')
train_3 = p.temp_val_train(df_full, 'date_posted', '2013-04-30')

#test data
test_1 = p.temp_val_test(df_full, 'date_posted', '2012-07-01', '2012-10-31')
test_2 = p.temp_val_test(df_full, 'date_posted', '2013-01-01', '2013-04-30')
test_3 = p.temp_val_test(df_full, 'date_posted', '2013-07-01', '2013-10-31')

#train test splits
X_train_1, X_test_1, y_train_1, y_test_1 = p.extract_train_test(train_1, test_1, dep_var, pred_vars)
X_train_2, X_test_2, y_train_2, y_test_2 = p.extract_train_test(train_2, test_2, dep_var, pred_vars)
X_train_3, X_test_3, y_train_3, y_test_3 = p.extract_train_test(train_3, test_3, dep_var, pred_vars)

# %%
#automated method, based on Rayid function
splits = p.temporal_validate('2012-01-01', '2013-12-31', [6], 60)

# %%
#NOW WE HAVE A LIST OF TRAIN/TEST GROUPS. WE NEED TO CLEAN THE DATA

# %%
train_test_dfs = p.temporal_split_train_test_dfs(df, dep_var, pred_vars, splits)

# %%
len(train_test_dfs)
# Out:
# 6

# %%
df_1 = train_test_dfs[0]

# %%
df_1
# Out:
#                                projectid                    teacher_acctid  \
# 1       0000fa3aa8f6649abab23615b546016d  2a578595fe351e7fce057e048c409b18
# 2       000134f07d4b30140d63262c871748ff  26bd60377bdbffb53a644a16c5308e82
# 16      000be0b57987d6c29d650a88eac2961b  ae7b6b599922817b2e0cb9f96354297e
# 18      000e6a13fd69bf0e426403b1d5da0e99  1ad348085983de6a0f1fe6a37779f7f2
# 23      00105edf14ebb7f146d6ba2098639bb1  ac1ef23232ddd1597f6fa5b28a171fa5
# 25      00134d14226ef613134712c54211f754  5bce35e3991721b665d33095e9d3aa31
# 27      0013a402fb4cf84e3d60d7a59566dff8  511ec2a1372cd7b9e1af86b1b3de8bff
# 30      0014d10f538cd1a7d97053f4d653f1f6  f6b048bad494f33ed7b3fc538789722b
# 33      001706ada83ac3f90369cdd3915d2dcf  5f4c7a2eb2656e33d3b6eca968b2e88d
# 37      00199bf192b852aa21573c69ed14565e  b6ac98079d8abaefa5353d15d708da9a
# 42      001d5055cf26a15651c3def86c6d6372  84c3f17b95688643d4f50a1f4d433ab7
# 53      0023f4e20e9ac0d53d7f1436d5711c5b  fc84d4b8fb44b111c70b5e6352954a5c
# 58      0024f9ac77374c0aac865543bb78eb46  4e1068729138de4b31a3eb253dbf7be8
# 59      00250a8ddc3f0223ac383aeeaa48c2f1  f3e2eb3fcbd5ae8be5af0d618aa546cb
# 61      00253a9de723379d8b86d5b08b7d46ff  f6e49c926016f27a5e75d4229125b660
# 74      002f926c33d27d1a5e917186b786335d  3132fa6d98eb5cb75ad254bf585ef525
# 87      0035903dc05abc095cb4663a5fc9ac53  1e7d32afe4de38aeba1f0e85cb5969f3
# 90      00377c2e78f1aa128fc1a509ed7b9213  442cff1ac9ba42e5dfcbbe3d924f4c07
# 98      003a0f03bd7f9114bf5b7357fc141277  7e57086c76d5d4d89b274187ba3c5fd1
# 107     003d3562242b7e73640af426d28016bb  21a51609e77447b0a334778325950d2f
# 114     004192554c05a6b6089be4504d4ca36f  2f49276c09b35e5e5dab9f5d54378af8
# 115     0042038709f10338dcccdfa92018df13  4771f6b65c60845859c4bea41bb8e270
# 116     00421922f0441ca75d1ce005d7ff0964  3cedb1cf6ada7d0616d382948dd58e25
# 134     004cd3e50be74ac3fa3758f385bfec2e  fbf39a9a592bc57b4de57b9a7878709e
# 107          -120.100601          Huron           CA          NaN
# 114          -118.355012       Lawndale           CA     suburban
# 115          -118.316475        Gardena           CA        urban
# 116          -122.274277        Oakland           CA        urban
# 134           -71.077745        Roxbury           MA        urban
# 137          -118.504257  Granada Hills           CA        urban
# 142          -118.299099      San Pedro           CA        urban
# 144           -73.986275       Brooklyn           NY        urban
# 146           -74.398670     Middletown           NY          NaN
# 148           -82.939972       Littcarr           KY        rural
# 167          -122.510017      Vancouver           WA        urban
# ...                  ...            ...          ...          ...
# 124792       -118.303978      San Pedro           CA        urban
# 124807        -81.436996        Orlando           FL        urban
# 124817       -118.398254    Los Angeles           CA        urban
# 124830       -118.246624    Los Angeles           CA        urban
# 124844        -91.902570        Oelwein           IA          NaN
# 124845       -118.345695    Los Angeles           CA        urban
# 124852       -121.365250     Sacramento           CA     suburban
# 124858        -95.717547       Richmond           TX        rural
# 124861       -118.259144         Carson           CA        urban
# 124863        -97.339745     Fort Worth           TX        urban
# 124864        -93.096095   Natchitoches           LA          NaN
# 124869        -80.729477      Charlotte           NC        urban
# 124879        -84.991043       Columbus           GA        urban
# 124887        -89.821094   Olive Branch           MS        rural
# 124898       -121.585438         Gilroy           CA     suburban
# 124906        -74.223553         Newark           NJ        urban
# 124908        -71.050228         Boston           MA        urban
# 124909        -84.972914       Columbus           GA        urban
# 124914        -74.009758       Brooklyn           NY        urban
# 124915        -85.798521   Mc Minnville           TN        rural
# 124922        -84.177075    Barnesville           GA          NaN
# 124926        -95.615753         Topeka           KS     suburban
# 124927        -73.903357          Bronx           NY        urban
# 124928       -118.246624    Los Angeles           CA        urban
# 124931        -77.077049     Kensington           MD     suburban
# 124937       -121.648661    Morgan Hill           CA     suburban
# 124957       -118.211122    Los Angeles           CA        urban
# 124962       -122.168290        Oakland           CA        urban
# 124966       -122.430496  San Francisco           CA        urban
# 124974       -105.031563    Westminster           CO     suburban
#
#                                   school_district       ...        \
# 1                    Ventura Unif School District       ...
# 2                       Los Angeles Unif Sch Dist       ...
# 16                      Hardin Co School District       ...
# 18                      Los Angeles Unif Sch Dist       ...
# 23      Mountain View School District-Los Angeles       ...
# 25                   Washington Township Sch Dist       ...
# 27                      Los Angeles Unif Sch Dist       ...
# 30                      Los Angeles Unif Sch Dist       ...
# 33                   Bridgeport City Sch District       ...
# 37                       New York City Dept Of Ed       ...
# 42                       New York City Dept Of Ed       ...
# 53                      Los Angeles Unif Sch Dist       ...
# 58                  Carroll Co Public School Dist       ...
# 59                      Los Angeles Unif Sch Dist       ...
# 61                     South Pike School District       ...
# 74                  Des Moines Public School Dist       ...
# 87                 San Francisco Unified Sch Dist       ...
# 90                       Milwaukee Public Schools       ...
# 98                      Los Angeles Unif Sch Dist       ...
# 107                  Coalinga-Huron Joint Unif Sd       ...
# 114                   Los Angeles Co Office of Ed       ...
# 115                     Los Angeles Unif Sch Dist       ...
# 116                   Oakland Unified School Dist       ...
# 134                 Boston Public School District       ...
# 137                     Los Angeles Unif Sch Dist       ...
# 142                     Los Angeles Unif Sch Dist       ...
# 144                      New York City Dept Of Ed       ...
# ...                                  ...         ...             ...
# 124792                                 f  2012-02-05          3/4/12
# 124807                                 f  2012-04-12         7/24/12
# 124817                                 f  2012-03-08          4/4/12
# 124830                                 t  2012-01-20          3/3/12
# 124844                                 f  2012-03-26          4/5/12
# 124845                                 t  2012-01-30         3/23/12
# 124852                                 f  2012-02-06          5/1/12
# 124858                                 t  2012-02-13         3/27/12
# 124861                                 t  2012-01-30          5/5/12
# 124863                                 f  2012-02-09         2/20/12
# 124864                                 f  2012-01-01          2/2/12
# 124869                                 f  2012-04-15         5/25/12
# 124879                                 t  2012-02-26         3/20/12
# 124887                                 f  2012-02-09         5/14/12
# 124898                                 f  2012-03-01         3/11/12
# 124906                                 f  2012-04-12          6/3/12
# 124908                                 f  2012-01-22         4/15/12
# 124909                                 f  2012-04-14         4/28/12
# 124914                                 f  2012-02-29         3/13/12
# 124915                                 t  2012-03-19         4/23/12
# 124922                                 f  2012-02-21          6/9/12
# 124926                                 f  2012-02-19         6/18/12
# 124927                                 f  2012-01-16          5/3/12
# 124928                                 t  2012-02-02         2/17/12
# 124931                                 f  2012-02-10         3/15/12
# 124937                                 f  2012-02-28          5/5/12
# 124957                                 t  2012-01-28          3/5/12
# 124962                                 t  2012-04-03         4/13/12
# 124966                                 f  2012-02-17         4/12/12
# 124974                                 f  2012-01-14         1/29/12
#
# [21180 rows x 26 columns]

# %% [markdown]
# ### RUN THE MODELS, OUTPUT RESULTS

# %%
results_df = p.run_models({'knn': KNeighborsClassifier(), 
                         'random_forest': RandomForestClassifier(),
                         'decision_tree': DecisionTreeClassifier(),
                         'logistic_regression': LogisticRegression(),
                         'boosting': AdaBoostClassifier(),
                         'bagging': BaggingClassifier()}, 
                        {'period_1':(X_train_1, X_test_1, y_train_1, y_test_1), 
                                                           'period_2':(X_train_2, X_test_2, y_train_2, y_test_2), 
                                                           'period_3':(X_train_3, X_test_3, y_train_3, y_test_3)}, 
                        [0.01, 0.02, 0.05, 0.10, 0.20, 0.30, 0.50])

# %%
results_df
# Out:
#              model_name time_period  threshold  accuracy  precision    recall  \
# 0               bagging    period_1       0.01  0.329266   0.271440  0.954691
# 0               bagging    period_1       0.02  0.329327   0.271458  0.954691
# 0               bagging    period_1       0.05  0.329388   0.271430  0.954335
# 0               bagging    period_1       0.10  0.429116   0.291491  0.852449
# 0               bagging    period_1       0.20  0.523292   0.311836  0.707152
# 0               bagging    period_1       0.30  0.604930   0.334141  0.539912
# 0               bagging    period_1       0.50  0.705879   0.381697  0.231527
# 0               bagging    period_2       0.01  0.394578   0.335696  0.942364
# 0               bagging    period_2       0.02  0.394578   0.335696  0.942364
# 0               bagging    period_2       0.05  0.394671   0.335697  0.942070
# 0               bagging    period_2       0.10  0.481200   0.359429  0.827683
# 0               bagging    period_2       0.20  0.559140   0.386037  0.677329
# 0               bagging    period_2       0.30  0.616609   0.412275  0.510908
# 0               bagging    period_2       0.50  0.678581   0.476729  0.211380
# 0               bagging    period_3       0.01  0.365879   0.304197  0.953651
# 0               bagging    period_3       0.02  0.365947   0.304220  0.953651
# 0               bagging    period_3       0.05  0.366287   0.304316  0.953492
# 0               bagging    period_3       0.10  0.457280   0.328036  0.864697
# 0               bagging    period_3       0.20  0.541881   0.352449  0.727801
# 0               bagging    period_3       0.30  0.611316   0.378411  0.568687
# 0               bagging    period_3       0.50  0.694943   0.437948  0.252927
# 0              boosting    period_1       0.01  0.257207   0.257207  1.000000
# 0              boosting    period_1       0.02  0.257207   0.257207  1.000000
# 0              boosting    period_1       0.05  0.257207   0.257207  1.000000
# 0              boosting    period_1       0.10  0.257207   0.257207  1.000000
# 0              boosting    period_1       0.20  0.257207   0.257207  1.000000
# 0              boosting    period_1       0.30  0.257207   0.257207  1.000000
# 0              boosting    period_1       0.50  0.729583   0.431639  0.162140
# 0              boosting    period_2       0.01  0.314920   0.314920  1.000000
# 0              boosting    period_2       0.02  0.314920   0.314920  1.000000
# ..                  ...         ...        ...       ...        ...       ...
# 0   logistic_regression    period_2       0.30  0.588293   0.391980  0.557636
# 0   logistic_regression    period_2       0.50  0.685127   0.502242  0.016509
# 0   logistic_regression    period_3       0.01  0.284655   0.284655  1.000000
# 0   logistic_regression    period_3       0.02  0.284655   0.284655  1.000000
# 0   logistic_regression    period_3       0.05  0.284655   0.284655  1.000000
# 0   logistic_regression    period_3       0.10  0.284655   0.284655  1.000000
# 0   logistic_regression    period_3       0.20  0.333711   0.294940  0.964163
# 0   logistic_regression    period_3       0.30  0.590710   0.360768  0.567253
# 0   logistic_regression    period_3       0.50  0.713440   0.456341  0.034961
# 0         random_forest    period_1       0.01  0.325971   0.270501  0.955047
# 0         random_forest    period_1       0.02  0.325971   0.270501  0.955047
# 0         random_forest    period_1       0.05  0.326154   0.270525  0.954810
# 0         random_forest    period_1       0.10  0.428628   0.291471  0.853635
# 0         random_forest    period_1       0.20  0.527868   0.313575  0.702764
# 0         random_forest    period_1       0.30  0.611245   0.336518  0.526391
# 0         random_forest    period_1       0.50  0.709601   0.384697  0.215277
# 0         random_forest    period_2       0.01  0.390679   0.334551  0.945165
# 0         random_forest    period_2       0.02  0.390679   0.334551  0.945165
# 0         random_forest    period_2       0.05  0.390911   0.334586  0.944723
# 0         random_forest    period_2       0.10  0.488998   0.364128  0.834316
# 0         random_forest    period_2       0.20  0.569956   0.393872  0.678361
# 0         random_forest    period_2       0.30  0.629236   0.424520  0.498673
# 0         random_forest    period_2       0.50  0.683223   0.491961  0.180425
# 0         random_forest    period_3       0.01  0.361209   0.302782  0.955005
# 0         random_forest    period_3       0.02  0.361209   0.302782  0.955005
# 0         random_forest    period_3       0.05  0.361390   0.302824  0.954846
# 0         random_forest    period_3       0.10  0.462562   0.330691  0.867245
# 0         random_forest    period_3       0.20  0.554689   0.360156  0.726766
# 0         random_forest    period_3       0.30  0.624215   0.387622  0.552122
# 0         random_forest    period_3       0.50  0.698275   0.440191  0.220674
#
#           f1   auc_roc
# 0   0.422697  0.533695
# 0   0.422719  0.533736
# 0   0.422651  0.533661
# 0   0.434430  0.567489
# 0   0.432813  0.583390
# 0   0.412805  0.583678
# 0   0.288224  0.550830
# 0   0.495044  0.542567
# 0   0.495044  0.542567
# 0   0.495004  0.542555
# 0   0.501205  0.574805
# 0   0.491786  0.591070
# 0   0.456323  0.588053
# 0   0.292892  0.552363
# 0   0.461260  0.542819
# 0   0.461287  0.542867
# 0   0.461378  0.543057
# 0   0.475634  0.579927
# 0   0.474914  0.597850
# 0   0.454436  0.598483
# 0   0.320662  0.561880
# 0   0.409173  0.500000
# 0   0.409173  0.500000
# 0   0.409173  0.500000
# 0   0.409173  0.500000
# 0   0.409173  0.500000
# 0   0.409173  0.500000
# 0   0.235730  0.544106
# 0   0.478995  0.500000
# 0   0.478995  0.500000
# ..       ...       ...
# 0   0.460359  0.580010
# 0   0.031968  0.504494
# 0   0.443162  0.500000
# 0   0.443162  0.500000
# 0   0.443162  0.500000
# 0   0.443162  0.500000
# 0   0.451703  0.523500
# 0   0.441039  0.583649
# 0   0.064946  0.509193
# 0   0.421593  0.531594
# 0   0.421593  0.531594
# 0   0.421598  0.531639
# 0   0.434562  0.567548
# 0   0.433653  0.585035
# 0   0.410565  0.583509
# 0   0.276067  0.548024
# 0   0.494181  0.540478
# 0   0.494181  0.540478
# 0   0.494159  0.540528
# 0   0.506987  0.582289
# 0   0.498376  0.599243
# 0   0.458619  0.593963
# 0   0.264021  0.547388
# 0   0.459790  0.539963
# 0   0.459790  0.539963
# 0   0.459819  0.540042
# 0   0.478808  0.584386
# 0   0.481634  0.606490
# 0   0.455474  0.602513
# 0   0.293974  0.554500
#
# [126 rows x 8 columns]

# %%
results_df.to_csv('data_output.csv')

# %%
filtered_df = results_df.loc[results_df['threshold'] == 0.05]

# %%
filtered_df.sort_values(by=['f1'], ascending=False)
# Out:
#             model_name time_period  threshold  accuracy  precision    recall  \
# 0              bagging    period_2       0.05  0.394671   0.335697  0.942070
# 0        random_forest    period_2       0.05  0.390911   0.334586  0.944723
# 0                  knn    period_2       0.05  0.482128   0.356618  0.801445
# 0             boosting    period_2       0.05  0.314920   0.314920  1.000000
# 0  logistic_regression    period_2       0.05  0.314920   0.314920  1.000000
# 0                  knn    period_3       0.05  0.443792   0.321428  0.858565
# 0              bagging    period_3       0.05  0.366287   0.304316  0.953492
# 0        random_forest    period_3       0.05  0.361390   0.302824  0.954846
# 0             boosting    period_3       0.05  0.284655   0.284655  1.000000
# 0  logistic_regression    period_3       0.05  0.284655   0.284655  1.000000
# 0                  knn    period_1       0.05  0.412185   0.282817  0.836911
# 0              bagging    period_1       0.05  0.329388   0.271430  0.954335
# 0        random_forest    period_1       0.05  0.326154   0.270525  0.954810
# 0  logistic_regression    period_1       0.05  0.257207   0.257207  1.000000
# 0             boosting    period_1       0.05  0.257207   0.257207  1.000000
# 0        decision_tree    period_2       0.05  0.616563   0.387225  0.373526
# 0        decision_tree    period_3       0.05  0.622492   0.356079  0.403520
# 0        decision_tree    period_1       0.05  0.622045   0.314874  0.399241
#
#          f1   auc_roc
# 0  0.495004  0.542555
# 0  0.494159  0.540528
# 0  0.493600  0.568394
# 0  0.478995  0.500000
# 0  0.478995  0.500000
# 0  0.467743  0.568654
# 0  0.461378  0.543057
# 0  0.459819  0.540042
# 0  0.443162  0.500000
# 0  0.443162  0.500000
# 0  0.422768  0.551013
# 0  0.422651  0.533661
# 0  0.421598  0.531639
# 0  0.409173  0.500000
# 0  0.409173  0.500000
# 0  0.380252  0.550904
# 0  0.378318  0.556574
# 0  0.352074  0.549218

# %%
#special run for svm, has confidence_score instead of prediction_score
results_df_conf = p.run_models_conf({'svm_model': LinearSVC()}, 
                        {'period_1':(X_train_1, X_test_1, y_train_1, y_test_1), 
                                                           'period_2':(X_train_2, X_test_2, y_train_2, y_test_2), 
                                                           'period_3':(X_train_3, X_test_3, y_train_3, y_test_3)}, 
                        [-1, -0.9, -0.8, -0.7, -0.6, -0.5, -0.4, -0.3, -0.2, -0.1, 0])

# %%
results_df_conf
# Out:
#   model_name time_period  threshold  accuracy  precision    recall        f1  \
# 0  svm_model    period_1       -1.0  0.263278   0.257303  0.988258  0.408301
# 0  svm_model    period_1       -0.9  0.265810   0.257168  0.981971  0.407592
# 0  svm_model    period_1       -0.8  0.271637   0.257673  0.973906  0.407524
# 0  svm_model    period_1       -0.7  0.278746   0.258056  0.962163  0.406963
# 0  svm_model    period_1       -0.6  0.288325   0.258878  0.948523  0.406744
# 0  svm_model    period_1       -0.5  0.299948   0.259653  0.930020  0.405964
# 0  svm_model    period_1       -0.4  0.315629   0.261058  0.907247  0.405449
# 0  svm_model    period_1       -0.3  0.332835   0.261670  0.874985  0.402862
# 0  svm_model    period_1       -0.2  0.355868   0.263756  0.839758  0.401429
# 0  svm_model    period_1       -0.1  0.378260   0.264941  0.798719  0.397896
# 0  svm_model    period_1        0.0  0.402819   0.265705  0.749496  0.392326
# 0  svm_model    period_2       -1.0  0.597298   0.364832  0.376179  0.370419
# 0  svm_model    period_2       -0.9  0.635410   0.380260  0.250442  0.301991
# 0  svm_model    period_2       -0.8  0.658481   0.387955  0.146226  0.212397
# 0  svm_model    period_2       -0.7  0.674403   0.408439  0.075619  0.127612
# 0  svm_model    period_2       -0.6  0.682341   0.440404  0.032134  0.059898
# 0  svm_model    period_2       -0.5  0.684895   0.489130  0.013267  0.025832
# 0  svm_model    period_2       -0.4  0.685220   0.522388  0.005159  0.010217
# 0  svm_model    period_2       -0.3  0.685545   0.656250  0.003096  0.006162
# 0  svm_model    period_2       -0.2  0.685405   0.666667  0.002064  0.004115
# 0  svm_model    period_2       -0.1  0.685220   0.600000  0.001327  0.002647
# 0  svm_model    period_2        0.0  0.685080   0.500000  0.000737  0.001472
# 0  svm_model    period_3       -1.0  0.353275   0.295357  0.917894  0.446909
# 0  svm_model    period_3       -0.9  0.374810   0.299396  0.892729  0.448409
# 0  svm_model    period_3       -0.8  0.402308   0.304344  0.855300  0.448940
# 0  svm_model    period_3       -0.7  0.439757   0.312594  0.807438  0.450702
# 0  svm_model    period_3       -0.6  0.479836   0.321071  0.742295  0.448254
# 0  svm_model    period_3       -0.5  0.519212   0.329939  0.668392  0.441795
# 0  svm_model    period_3       -0.4  0.554598   0.337668  0.587322  0.428804
# 0  svm_model    period_3       -0.3  0.584862   0.343366  0.502429  0.407940
# 0  svm_model    period_3       -0.2  0.609888   0.348172  0.424783  0.382681
# 0  svm_model    period_3       -0.1  0.630472   0.351523  0.352951  0.352235
# 0  svm_model    period_3        0.0  0.647791   0.354293  0.288524  0.318044
#
#     auc_roc
# 0  0.500248
# 0  0.499898
# 0  0.501184
# 0  0.502131
# 0  0.504120
# 0  0.505896
# 0  0.509008
# 0  0.510045
# 0  0.514035
# 0  0.515693
# 0  0.516135
# 0  0.537561
# 0  0.531408
# 0  0.520091
# 0  0.512637
# 0  0.506682
# 0  0.503449
# 0  0.501495
# 0  0.501175
# 0  0.500795
# 0  0.500460
# 0  0.500199
# 0  0.523246
# 0  0.530723
# 0  0.538675
# 0  0.550442
# 0  0.558846
# 0  0.564121
# 0  0.564449
# 0  0.560046
# 0  0.554165
# 0  0.546928
# 0  0.539639

# %%
results_df_conf.to_csv('data_output_conf.csv')

# %%
#run some precision/recall curves based on function in pipeline

# %%
y_test, y_pred, pred_scores = p.knn(X_train_1, X_test_1, y_train_1, y_test_1)

# %%
p.plot_precision_recall(pred_scores[:,1], y_test)

# %% [markdown]
# ### EXPERIMENT WITH DIFFERENT PARAMETERS FOR THESE CLASSIFIERS

# %%
#1) Experiment with different parameters for these classifiers 
#(different values of k for example, as well as parameters that other classifiers have). 
#You should look at the sklearn documentation to see what parameter each classifier 
#can take and what the default values sklearn selects. The labs should be helpful here.

# %%
bagging = BaggingClassifier() # use the default parameters: base_estimator is a decision tree, n_estimators=10
bagging.fit(X_train_1, y_train_1)
pred_scores = bagging.predict_proba(X_test_1)

# %%
print("The true number of HBP is {}/{} from the testing data, with percentage {:.2f}%\n".format(
    sum(y_test), len(y_test), 100.*sum(y_test)/len(y_test)))
for threshold in np.linspace(0.1,0.7,7):
    pred_label = [1 if x[1]>threshold else 0 for x in pred_scores]
    print("(Threshold: {}), the total number of predicted HBP is {}, the accuracy is {:.2f}, the f1_score is {:.2f}".format(
        threshold, sum(pred_label), accuracy_score(pred_label,y_test), f1_score(y_test, pred_label)))
    print
# Out:
# The true number of HBP is 8431/32779 from the testing data, with percentage 25.72%
#
# (Threshold: 0.1), the total number of predicted HBP is 24990, the accuracy is 0.42, the f1_score is 0.43
# (Threshold: 0.2), the total number of predicted HBP is 19545, the accuracy is 0.52, the f1_score is 0.43
# (Threshold: 0.3), the total number of predicted HBP is 14100, the accuracy is 0.60, the f1_score is 0.41
# (Threshold: 0.4), the total number of predicted HBP is 9338, the accuracy is 0.66, the f1_score is 0.37
# (Threshold: 0.5), the total number of predicted HBP is 5625, the accuracy is 0.70, the f1_score is 0.30
# (Threshold: 0.6), the total number of predicted HBP is 2965, the accuracy is 0.72, the f1_score is 0.21
# (Threshold: 0.7), the total number of predicted HBP is 1250, the accuracy is 0.74, the f1_score is 0.11

# %%
#based on runs above, threshold 4 is a good option - balance of accuracy and f_1

# %%
#now, let's use different models inside bagging
fpr, tpr, thresholds = roc_curve(y_test_1, pred_scores[:,1], pos_label=1)
print("The AUC under the original default setting of bagging is {:.3f}".format(auc(fpr, tpr)))
# Out:
# The AUC under the original default setting of bagging is 0.617

# %%
bagging = BaggingClassifier(base_estimator=LogisticRegression()) # use the default parameters: base_estimator is a decision tree, n_estimators=10
bagging.fit(X_train_1, y_train_1)
pred_scores = bagging.predict_proba(X_test_1)
fpr, tpr, thresholds = roc_curve(y_test_1, pred_scores[:,1], pos_label=1)
print("The AUC of bagging with Logistic Regression as base_estimator is {:.3f}".format(auc(fpr, tpr)))
# Out:
# The AUC of bagging with Logistic Regression as base_estimator is 0.603

# %%
#in this case, Logistic Regression does NOT improve the base estimator, as AUC goes down
